# %% [markdown]
# <a href="https://colab.research.google.com/github/chiusanghung/Stock-Prediction/blob/main/PNJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load_data
df_link = '/content/drive/MyDrive/Dataset/PNJ.csv'

df = pd.read_csv(df_link, index_col='Date/Time', parse_dates=True)

# %%
#Take data
df1=pd.DataFrame(df,columns=('Date/Time','Close'))
df1.drop("Date/Time",axis=1,inplace=True)

# %%
plt.figure(figsize=(20,8))
plt.plot(df1['Close'], label='Actual', color='red')
plt.title('MSN')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
df1
# Out:
#                      Close
# Date/Time
# 2018-02-28 09:15:00  78.99
# 2018-02-28 09:16:00  78.94
# 2018-02-28 09:19:00  78.14
# 2018-02-28 09:20:00  78.14
# 2018-02-28 09:21:00  78.14
# ...                    ...
# 2020-12-22 14:22:00  78.20
# 2020-12-22 14:23:00  78.20
# 2020-12-22 14:24:00  78.20
# 2020-12-22 14:25:00  78.10
# 2020-12-22 14:46:00  78.30
#
# [125309 rows x 1 columns]

# %%
data = df1.values
train_data = data[:95000]
test_data = data[95000:]
data
# Out:
# array([[78.99],
#        [78.94],
#        [78.14],
#        ...,
#        [78.2 ],
#        [78.1 ],
#        [78.3 ]])

# %%
sc = MinMaxScaler(feature_range = (0,1))
sc_train = sc.fit_transform(data)

# %%
x_train, y_train = [],[]
for i in range(50, len(train_data)):
  x_train.append(sc_train[i-50:i, 0])
  y_train.append(sc_train[i, 0])

#1 mang
x_train = np.array(x_train)
y_train = np.array(y_train)

#1 chieu
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
model = Sequential()
model.add(LSTM(units = 128, input_shape=(x_train.shape[1], 1), return_sequences = True))
model.add(LSTM(units = 64))
model.add(Dropout(0.5))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 128)           66560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 116033 (453.25 KB)
# Trainable params: 116033 (453.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
save_model='PNJ.hdf5'
best_model = ModelCheckpoint(save_model, monitor='loss',verbose=2,save_best_only=True,modee='auto')
model.fit(x_train,y_train,epochs=100, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.03546, saving model to PNJ.hdf5
# 1899/1899 - 20s - loss: 0.0355 - 20s/epoch - 10ms/step
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: loss improved from 0.03546 to 0.01794, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0179 - 12s/epoch - 6ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.01794 to 0.01762, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0176 - 12s/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.01762 to 0.01739, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0174 - 12s/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01739 to 0.01731, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0173 - 12s/epoch - 6ms/step
# Epoch 6/100
#
# Epoch 6: loss did not improve from 0.01731
# 1899/1899 - 12s - loss: 0.0173 - 12s/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.01731 to 0.01729, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0173 - 12s/epoch - 6ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.01729 to 0.01708, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0171 - 12s/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.01708
# 1899/1899 - 12s - loss: 0.0171 - 12s/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: loss did not improve from 0.01708
# 1899/1899 - 12s - loss: 0.0171 - 12s/epoch - 6ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.01708 to 0.01699, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0170 - 12s/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.01699
# 1899/1899 - 12s - loss: 0.0170 - 12s/epoch - 6ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.01699
# 1899/1899 - 12s - loss: 0.0171 - 12s/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01699 to 0.01686, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.01686
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01686 to 0.01686, saving model to PNJ.hdf5
# 1899/1899 - 11s - loss: 0.0169 - 11s/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01686
# 1899/1899 - 13s - loss: 0.0169 - 13s/epoch - 7ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01686
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.01686
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: loss improved from 0.01686 to 0.01685, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.01685 to 0.01679, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01679
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01679
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01679
# 1899/1899 - 11s - loss: 0.0168 - 11s/epoch - 6ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01679
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.01679 to 0.01679, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01679
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01679
# 1899/1899 - 12s - loss: 0.0169 - 12s/epoch - 6ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01679 to 0.01672, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01672 to 0.01669, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01669
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01669
# 1899/1899 - 11s - loss: 0.0168 - 11s/epoch - 6ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01669
# 1899/1899 - 12s - loss: 0.0168 - 12s/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01669
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01669
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 36/100
#
# Epoch 36: loss improved from 0.01669 to 0.01669, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 37/100
#
# Epoch 37: loss improved from 0.01669 to 0.01667, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01667
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 39/100
#
# Epoch 39: loss improved from 0.01667 to 0.01664, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01664
# 1899/1899 - 11s - loss: 0.0167 - 11s/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01664
# 1899/1899 - 11s - loss: 0.0167 - 11s/epoch - 6ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01664
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01664
# 1899/1899 - 13s - loss: 0.0167 - 13s/epoch - 7ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01664
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: loss improved from 0.01664 to 0.01662, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 46/100
#
# Epoch 46: loss improved from 0.01662 to 0.01655, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01655
# 1899/1899 - 11s - loss: 0.0166 - 11s/epoch - 6ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01655
# 1899/1899 - 11s - loss: 0.0167 - 11s/epoch - 6ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01655
# 1899/1899 - 11s - loss: 0.0166 - 11s/epoch - 6ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01655
# 1899/1899 - 11s - loss: 0.0167 - 11s/epoch - 6ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01655
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 59/100
#
# Epoch 59: loss improved from 0.01655 to 0.01651, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 60/100
#
# Epoch 60: loss improved from 0.01651 to 0.01647, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01647
# 1899/1899 - 11s - loss: 0.0166 - 11s/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01647
# 1899/1899 - 11s - loss: 0.0165 - 11s/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01647
# 1899/1899 - 11s - loss: 0.0166 - 11s/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0167 - 12s/epoch - 6ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01647
# 1899/1899 - 11s - loss: 0.0166 - 11s/epoch - 6ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01647
# 1899/1899 - 11s - loss: 0.0165 - 11s/epoch - 6ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01647
# 1899/1899 - 12s - loss: 0.0166 - 12s/epoch - 6ms/step
# Epoch 87/100
#
# Epoch 87: loss improved from 0.01647 to 0.01646, saving model to PNJ.hdf5
# 1899/1899 - 11s - loss: 0.0165 - 11s/epoch - 6ms/step
# Epoch 88/100
#
# Epoch 88: loss improved from 0.01646 to 0.01641, saving model to PNJ.hdf5
# 1899/1899 - 12s - loss: 0.0164 - 12s/epoch - 6ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01641
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01641
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01641
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01641
# 1899/1899 - 12s - loss: 0.0164 - 12s/epoch - 6ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01641
# 1899/1899 - 12s - loss: 0.0165 - 12s/epoch - 6ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01641
# 1899/1899 - 11s - loss: 0.0165 - 11s/epoch - 6ms/step
# Epoch 95/100
#
# Epoch 95: loss improved from 0.01641 to 0.01633, saving model to PNJ.hdf5
# 1899/1899 - 11s - loss: 0.0163 - 11s/epoch - 6ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01633
# 1899/1899 - 12s - loss: 0.0164 - 12s/epoch - 6ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01633
# 1899/1899 - 12s - loss: 0.0163 - 12s/epoch - 6ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01633
# 1899/1899 - 14s - loss: 0.0164 - 14s/epoch - 7ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01633
# 1899/1899 - 12s - loss: 0.0164 - 12s/epoch - 6ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01633
# 1899/1899 - 12s - loss: 0.0164 - 12s/epoch - 6ms/step

# %%
model.save('/content/drive/MyDrive/Dataset/PNJ.h5')

# %%
y_train = sc.inverse_transform(y_train)
final_model = load_model('PNJ.hdf5')
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 2968/2968 [==============================] - 18s 5ms/step

# %%
#Test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test=[]
for i in range(50, test.shape[0]):
  x_test.append(sc_test[i-50:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

#data test
y_test = data[95000:]
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 948/948 [==============================] - 4s 4ms/step

# %%
train_data1 = df1[50:95000]
test_data1 = df1[95000:]

plt.figure(figsize=(24,8))
plt.plot(df1,label='Actual',color='red') #line actual
train_data1['Predict'] = y_train_predict #add data
plt.plot(train_data1['Predict'], label='train predict',color='green') #line train predict
test_data1['Predict'] = y_test_predict
plt.plot(test_data1['Predict'], label='test predict',color='blue') #line test predict
plt.title('MSN')
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.legend()
plt.show()
# Out:
# <ipython-input-20-046c17a67e45>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['Predict'] = y_train_predict #add data
# <ipython-input-20-046c17a67e45>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Predict'] = y_test_predict

# %%
print('Accuracy Score', r2_score(y_test, y_test_predict))
print('Average absolute error', mean_absolute_error(y_test, y_test_predict))
print('Mean absolute error percentage', mean_absolute_percentage_error(y_test, y_test_predict))
# Out:
# Accuracy Score 0.997995466762453
# Average absolute error 0.294743640885436
# Mean absolute error percentage 0.004640459226497659

# %%
train_data1
# Out:
#                      Close    Predict
# Date/Time
# 2018-02-28 10:23:00  78.61  78.493416
# 2018-02-28 10:24:00  78.61  78.472939
# 2018-02-28 10:27:00  80.32  78.452911
# 2018-02-28 10:28:00  78.71  78.751434
# 2018-02-28 10:31:00  78.61  78.592819
# ...                    ...        ...
# 2020-05-18 13:01:00  63.10  62.735115
# 2020-05-18 13:02:00  63.20  62.757053
# 2020-05-18 13:03:00  63.20  62.810230
# 2020-05-18 13:04:00  63.20  62.842510
# 2020-05-18 13:05:00  63.30  62.870674
#
# [94950 rows x 2 columns]

# %%
test_data1
# Out:
#                      Close    Predict
# Date/Time
# 2020-05-18 13:06:00   63.4  62.912083
# 2020-05-18 13:07:00   63.5  62.966984
# 2020-05-18 13:08:00   63.6  63.045807
# 2020-05-18 13:09:00   63.7  63.133469
# 2020-05-18 13:10:00   63.8  63.223145
# ...                    ...        ...
# 2020-12-22 14:22:00   78.2  78.015182
# 2020-12-22 14:23:00   78.2  78.012390
# 2020-12-22 14:24:00   78.2  78.007034
# 2020-12-22 14:25:00   78.1  77.996330
# 2020-12-22 14:46:00   78.3  77.966026
#
# [30309 rows x 2 columns]
